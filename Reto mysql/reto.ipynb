# %%
import pandas as pd
import seaborn as sns
import io 
from sqlalchemy import create_engine
from pandasql import sqldf

# %%
f = pd.read_csv('athlete_events.csv', delimiter=';')
f
# Out:
#          ID                      Name Sex  Age  Height  Weight  \
# 0         1                 A Dijiang   M   24   180.0    80.0
# 1         2                  A Lamusi   M   23   170.0    60.0
# 2         3       Gunnar Nielsen Aaby   M   24     NaN     NaN
# 3         4      Edgar Lindenau Aabye   M   34     NaN     NaN
# 4         5  Christine Jacoba Aaftink   F   21   185.0    82.0
# ...     ...                       ...  ..  ...     ...     ...
# 13086  7423                Marvin Bam   M   30   175.0    66.0
# 13087  7424          Souleymane Bamba   M   23   190.0    90.0
# 13088  7427               Paul Bamber   M   27   175.0    65.0
# 13089  7427               Paul Bamber   M   27   175.0    65.0
# 13090  7428           Ivano Bamberghi   M   27     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 0               China  CHN  1992 Summer  1992  Summer  Barcelona
# 1               China  CHN  2012 Summer  2012  Summer     London
# ...

# %% [markdown]
# ## 1. ¿Cuántos Juegos Olímpicos se han celebrado?

# %%
q = """
SELECT COUNT(DISTINCT Year) AS Total_Juegos FROM f;
"""

# Ejecutamos la consulta utilizando la función sqldf
Numero_juegos_olimpicos = sqldf(q)

Numero_juegos_olimpicos
# Out:
#    Total_Juegos
# 0            34

# %% [markdown]
# ##2. Enumera todos los Juegos Olimpicos celebrados hasta ahora

# %%
q = """
SELECT DISTINCT Games FROM f;
"""
# Ejecutamos la consulta utilizando la función sqldf
Enumera_juegos_olimpicos = sqldf(q)

Enumera_juegos_olimpicos
# Out:
#           Games
# 0   1992 Summer
# 1   2012 Summer
# 2   1920 Summer
# 3   1900 Summer
# 4   1988 Winter
# 5   1992 Winter
# 6   1994 Winter
# 7   1932 Summer
# 8   2002 Winter
# 9   1952 Summer
# 10  1980 Winter
# 11  2000 Summer
# 12  1996 Summer
# 13  1912 Summer
# 14  1924 Summer
# 15  2014 Winter
# 16  1948 Summer
# 17  1998 Winter
# 18  2006 Winter
# 19  2008 Summer
# 20  2016 Summer
# 21  2004 Summer
# 22  1960 Winter
# 23  1964 Winter
# 24  1984 Winter
# 25  1984 Summer
# 26  1968 Summer
# 27  1972 Summer
# 28  1988 Summer
# 29  1936 Summer
# 30  1952 Winter
# 31  1956 Winter
# 32  1956 Summer
# 33  1960 Summer
# 34  1928 Summer
# 35  1976 Summer
# 36  1980 Summer
# 37  1964 Summer
# 38  2010 Winter
# 39  1968 Winter
# 40  1972 Winter
# 41  1976 Winter
# 42  1924 Winter
# 43  1904 Summer
# 44  1906 Summer
# 45  1928 Winter
# 46  1908 Summer
# 47  1948 Winter
# 48  1932 Winter
# 49  1936 Winter

# %% [markdown]
# ##3. Menciona el numero total de naciones que participaron en cada Juego Olimpico.

# %%
q = """
SELECT Games, COUNT(DISTINCT NOC) AS Numero_de_naciones
FROM f
GROUP BY Games;
"""
# Ejecutamos la consulta utilizando la función sqldf
Numero_de_naciones = sqldf(q)

Numero_de_naciones
# Out:
#           Games  Numero_de_naciones
# 0   1900 Summer                   7
# 1   1904 Summer                   2
# 2   1906 Summer                   8
# 3   1908 Summer                  11
# 4   1912 Summer                  17
# 5   1920 Summer                  15
# 6   1924 Summer                  32
# 7   1924 Winter                   7
# 8   1928 Summer                  30
# 9   1928 Winter                   8
# 10  1932 Summer                  19
# 11  1932 Winter                   6
# 12  1936 Summer                  38
# 13  1936 Winter                  15
# 14  1948 Summer                  40
# 15  1948 Winter                  13
# 16  1952 Summer                  49
# 17  1952 Winter                  17
# 18  1956 Summer                  37
# 19  1956 Winter                  18
# 20  1960 Summer                  63
# 21  1960 Winter                  14
# 22  1964 Summer                  61
# 23  1964 Winter                  19
# 24  1968 Summer                  71
# ...

# %% [markdown]
# ##4. En que anio se vio el mayor y menor numero de paises participando en los juegos Olimpicos?

# %%
#No entiendo porque no funciona si esta funcionando en Workbench
q = """
(SELECT Year, COUNT(DISTINCT NOC) AS NumeroPaisesMax
FROM f
GROUP BY Year
ORDER BY NumeroPaisesMax DESC
LIMIT 1)
UNION
(SELECT Year, COUNT(DISTINCT NOC) AS NumeroPaisesMin
FROM f
GROUP BY Year
ORDER BY NumeroPaisesMin ASC
LIMIT 1);
"""
# Ejecutamos la consulta utilizando la función sqldf
Max_min_paises = sqldf(q)

Max_min_paises
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Cosette\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1970, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969     if not evt_handled:
# -> 1970         self.dialect.do_execute(
#    1971             cursor, str_statement, effective_parameters, context
#    1972         )
#    1974 if self._has_events or self.engine._has_events:
#
# File c:\Users\Cosette\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# OperationalError: near "(": syntax error
#
# ...

# %%
# Calcular el número de países únicos para cada año
num_paises_por_año = f.groupby('Year')['NOC'].nunique()

# Encontrar el año con el máximo número de países
max_paises_año = num_paises_por_año.idxmax()
max_num_paises = num_paises_por_año.max()

# Encontrar el año con el mínimo número de países
min_paises_año = num_paises_por_año.idxmin()
min_num_paises = num_paises_por_año.min()

print("Año con el máximo número de países:", max_paises_año, "Número de países:", max_num_paises)
print("Año con el mínimo número de países:", min_paises_año, "Número de países:", min_num_paises)
# Out:
# Año con el máximo número de países: 2016 Número de países: 135
# Año con el mínimo número de países: 1904 Número de países: 2

# %% [markdown]
# ##5. Que nacion a participado en todos los Juegos Olimpicos

# %%
q = """
SELECT NOC, COUNT(DISTINCT Year) AS Numero_de_participacion
FROM f
GROUP BY NOC
HAVING Numero_de_participacion = (SELECT COUNT(DISTINCT Year) FROM f);
"""
# Ejecutamos la consulta utilizando la función sqldf
Nacion_entodos = sqldf(q)

Nacion_entodos
# Out:
#    NOC  Numero_de_participacion
# 0  USA                       34

# %% [markdown]
# ## 6. Identifica el deporte que se jugo en todas las olimpiadas de verano

# %%
#funciona en workbecn pero no aqui por alguna razon

"""
q = 
CREATE TEMPORARY TABLE t3 AS 
SELECT Sport, COUNT(games) AS Numero_de_juegos
FROM (SELECT DISTINCT sport, games  
      FROM f
      WHERE Season = 'Summer' 
      ORDER BY games) AS X
GROUP BY Sport;

SELECT * FROM t3;

# Ejecutamos la consulta utilizando la función sqldf
deporte_todas = sqldf(q)

deporte_todas
"""
# Out:
# "\nq = \nCREATE TEMPORARY TABLE t3 AS \nSELECT Sport, COUNT(games) AS Numero_de_juegos\nFROM (SELECT DISTINCT sport, games  \n      FROM f\n      WHERE Season = 'Summer' \n      ORDER BY games) AS X\nGROUP BY Sport;\n\nSELECT * FROM t3;\n\n# Ejecutamos la consulta utilizando la función sqldf\ndeporte_todas = sqldf(q)\n\ndeporte_todas\n"

# %%
# Filtra los datos para incluir solo las Olimpiadas de verano
df_summer = f[f['Season'] == 'Summer']

# Agrupa por deporte y cuenta el número de juegos únicos para cada deporte
sports_counts = df_summer.groupby('Sport')['Games'].nunique()
# Encuentra los deportes que se jugaron en todas las Olimpiadas de verano
sports_count = df_summer['Year'].nunique()
print(sports_count)
sports_played_in_all_summer_olympics = sports_counts[sports_counts == df_summer['Year'].nunique()].index.tolist()

print("Deportes jugados en todas las Olimpiadas de verano:")
print(sports_played_in_all_summer_olympics)
# Out:
# 28
# Deportes jugados en todas las Olimpiadas de verano:
# ['Athletics', 'Swimming']

# %% [markdown]
# ## 7.Identifica el deporte que se jugo en todos los juegos Olimpicos de verano

# %%
q = """
SELECT DISTINCT Sport, count(DISTINCT Year) as Num_Years
FROM f
Where Season = 'Summer'
GROUP BY Sport
HAVING COUNT(DISTINCT Year) = (SELECT COUNT(DISTINCT Year) FROM f WHERE Season = 'Summer');
"""
# Ejecutamos la consulta utilizando la función sqldf
Deporte_todos_veranos = sqldf(q)

Deporte_todos_veranos
# Out:
#        Sport  Num_Years
# 0  Athletics         28
# 1   Swimming         28

# %% [markdown]
# ## obten el numero total de deportes jugados en cada juego olimpoco

# %%
q = """
SELECT DISTINCT Games, count(DISTINCT Sport) as Deportes_Jugados
FROM f
GROUP BY Games
"""
# Ejecutamos la consulta utilizando la función sqldf
Total_deportesxanio= sqldf(q)
Total_deportesxanio
# Out:
#           Games  Deportes_Jugados
# 0   1900 Summer                13
# 1   1904 Summer                 6
# 2   1906 Summer                 5
# 3   1908 Summer                19
# 4   1912 Summer                17
# 5   1920 Summer                22
# 6   1924 Summer                18
# 7   1924 Winter                 7
# 8   1928 Summer                17
# 9   1928 Winter                 6
# 10  1932 Summer                13
# 11  1932 Winter                 7
# 12  1936 Summer                22
# 13  1936 Winter                 8
# 14  1948 Summer                19
# 15  1948 Winter                 8
# 16  1952 Summer                19
# 17  1952 Winter                 6
# 18  1956 Summer                19
# 19  1956 Winter                 6
# 20  1960 Summer                19
# 21  1960 Winter                 5
# 22  1964 Summer                21
# 23  1964 Winter                 9
# 24  1968 Summer                20
# 25  1968 Winter                10
# ...

# %%
## Encuentra la proporcion de atletas masculino y femeninos que participaron en todos los juegos olimpicos

# %%
q = """
SELECT Year,
       SUM(CASE WHEN Sex = 'M' THEN 1 ELSE 0 END) AS Hombres,
       SUM(CASE WHEN Sex = 'F' THEN 1 ELSE 0 END) AS Mujeres,
       ROUND(SUM(CASE WHEN Sex = 'M' THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 2) AS Porcentaje_Hombres,
       ROUND(SUM(CASE WHEN Sex = 'F' THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 2) AS Porcentaje_Mujeres
FROM f
GROUP BY Year;
"""
# Ejecutamos la consulta utilizando la función sqldf
proporcion_hombres_mujeres= sqldf(q)
proporcion_hombres_mujeres
# Out:
#     Year  Hombres  Mujeres  Porcentaje_Hombres  Porcentaje_Mujeres
# 0   1900       30        2               93.75                6.25
# 1   1904       25        0              100.00                0.00
# 2   1906       22        0              100.00                0.00
# 3   1908      107        4               96.40                3.60
# 4   1912      187       11               94.44                5.56
# 5   1920      167        4               97.66                2.34
# 6   1924      177        7               96.20                3.80
# 7   1928      173       13               93.01                6.99
# 8   1932       87        9               90.63                9.38
# 9   1936      287       19               93.79                6.21
# 10  1948      276       32               89.61               10.39
# 11  1952      353       66               84.25               15.75
# 12  1956      208       31               87.03               12.97
# ...

# %% [markdown]
# ## Busca los 5 mejores atletas que han ganado la mayor cantidad de medallas de oro

# %%
q="""
Select Name,NOC, COUNT(*) as Total_Gold_Medals
from f
where Medal= 'Gold'
group by Name
order by Total_Gold_Medals desc
Limit 5;
"""
top_five = sqldf(q)

top_five
# Out:
#                            Name  NOC  Total_Gold_Medals
# 0  Nikolay Yefimovich Andrianov  URS                  7
# 1                     Viktor An  KOR                  6
# 2     Thomas Alsgaard (Alsgrd-)  NOR                  5
# 3   Polina Hryhorivna Astakhova  URS                  5
# 4        Nathan Ghar-Jun Adrian  USA                  5

# %% [markdown]
# ## 11. Obten los 3 mejores atletas que han ganado la mayoria de las medallas (oro/plata/bronce)

# %%
q="""
Select Name,NOC, 
COUNT(*) as Total_Medals,
COUNT(CASE WHEN Medal = 'Gold' THEN 1 END) AS Gold_Medals,
COUNT(CASE WHEN Medal = 'Silver' THEN 1 END) AS Silver_Medals,
COUNT(CASE WHEN Medal = 'Bronze' THEN 1 END) AS Bronze_Medals
from f
Where Medal IN ('Gold','Silver','Bronze')
group by Name
order by Total_Medals desc
Limit 5;
"""
top_five_medals = sqldf(q)

top_five_medals
# Out:
#                            Name  NOC  Total_Medals  Gold_Medals  \
# 0  Nikolay Yefimovich Andrianov  URS            15            7
# 1   Polina Hryhorivna Astakhova  URS            10            5
# 2     Shirley Frances Babashoff  USA             9            3
# 3                     Viktor An  KOR             8            6
# 4        Nathan Ghar-Jun Adrian  USA             8            5
#
#    Silver_Medals  Bronze_Medals
# 0              5              3
# 1              2              3
# 2              6              0
# 3              0              2
# 4              1              2

# %% [markdown]
# ## 12.Obten los 5 paises mas existosos en los juegos olimpicos
# --El exito se de define por el numer de medallas ganadas

# %%
q="""
Select NOC, 
COUNT(*) as Total_Medals,
COUNT(CASE WHEN Medal = 'Gold' THEN 1 END) AS Gold_Medals,
COUNT(CASE WHEN Medal = 'Silver' THEN 1 END) AS Silver_Medals,
COUNT(CASE WHEN Medal = 'Bronze' THEN 1 END) AS Bronze_Medals
from f
Where Medal IN ('Gold','Silver','Bronze')
group by NOC
order by Total_Medals desc
Limit 5;
"""
top_countries = sqldf(q)

top_countries
# Out:
#    NOC  Total_Medals  Gold_Medals  Silver_Medals  Bronze_Medals
# 0  USA           190           98             55             37
# 1  URS           148           60             36             52
# 2  SWE           126           28             49             49
# 3  ITA            86           37             26             23
# 4  GBR            83           29             25             29

# %% [markdown]
# ## Enumera el numero total de medallas de oro, plata y bronce por pais

# %%
q="""
Select NOC, 
COUNT(*) as Total_Medals,
COUNT(CASE WHEN Medal = 'Gold' THEN 1 END) AS Gold_Medals,
COUNT(CASE WHEN Medal = 'Silver' THEN 1 END) AS Silver_Medals,
COUNT(CASE WHEN Medal = 'Bronze' THEN 1 END) AS Bronze_Medals
from f
Where Medal IN ('Gold','Silver','Bronze')
group by NOC
order by Total_Medals desc

"""
medals_countries = sqldf(q)

medals_countries
# Out:
#     NOC  Total_Medals  Gold_Medals  Silver_Medals  Bronze_Medals
# 0   USA           190           98             55             37
# 1   URS           148           60             36             52
# 2   SWE           126           28             49             49
# 3   ITA            86           37             26             23
# 4   GBR            83           29             25             29
# ..  ...           ...          ...            ...            ...
# 83  GUY             1            0              0              1
# 84  CZE             1            0              0              1
# 85  BOT             1            0              1              0
# 86  BAH             1            0              1              0
# 87  ANZ             1            0              1              0
#
# [88 rows x 5 columns]

# %% [markdown]
# ## Enumera el numero total de medallas de oro, plata y bronce ganadas por cada pais en relacion con cada juego olimpico

# %%
q="""
SELECT
    Year,
    Season,
    NOC,
    SUM(CASE WHEN Medal = 'Gold' THEN 1 ELSE 0 END) AS Gold_Medals,
    SUM(CASE WHEN Medal = 'Silver' THEN 1 ELSE 0 END) AS Silver_Medals,
    SUM(CASE WHEN Medal = 'Bronze' THEN 1 ELSE 0 END) AS Bronze_Medals
FROM
    f
WHERE
    Medal IN ('Gold', 'Silver', 'Bronze')
GROUP BY
    Year,
    Season,
    NOC
ORDER BY
    Year,
    Season,
    NOC;

"""
medals_countries_year = sqldf(q)

medals_countries_year
# Out:
#    Year  Season  NOC  Total_Medals
# 0  1900  Summer  FRA             8

# %% [markdown]
# ## 15. Identifica que pais gano la mayoria de las medallas de oro, plata y bron en cada juego olimpico.

# %%
q="""
WITH MedalCounts AS (
    SELECT
        Year,
        Season,
        NOC,
        COUNT(CASE WHEN Medal = 'Gold' THEN 1 END) AS Gold_Medals,
        COUNT(CASE WHEN Medal = 'Silver' THEN 1 END) AS Silver_Medals,
        COUNT(CASE WHEN Medal = 'Bronze' THEN 1 END) AS Bronze_Medals
    FROM
        f
    WHERE
        Medal IN ('Gold', 'Silver', 'Bronze')
    GROUP BY
        Year,
        Season,
        NOC
)
SELECT
    Year,
    Season,
    NOC,
    CASE
        WHEN Gold_Medals >= Silver_Medals AND Gold_Medals >= Bronze_Medals THEN 'Gold'
        WHEN Silver_Medals >= Gold_Medals AND Silver_Medals >= Bronze_Medals THEN 'Silver'
        ELSE 'Bronze'
    END AS Most_Common_Medal,
    CASE
        WHEN Gold_Medals >= Silver_Medals AND Gold_Medals >= Bronze_Medals THEN Gold_Medals
        WHEN Silver_Medals >= Gold_Medals AND Silver_Medals >= Bronze_Medals THEN Silver_Medals
        ELSE Bronze_Medals
    END AS Num_Most_Common_Medal
FROM
    MedalCounts
ORDER BY
    Year,
    Season,
    NOC;

"""
medals_countries_olimpicgame = sqldf(q)

medals_countries_olimpicgame
# Out:
#      Year  Season  NOC Most_Common_Medal  Num_Most_Common_Medal
# 0    1900  Summer  DEN              Gold                      1
# 1    1900  Summer  FRA              Gold                      6
# 2    1900  Summer  GBR            Silver                      1
# 3    1900  Summer  GER            Silver                      1
# 4    1900  Summer  NOR            Bronze                      1
# ..    ...     ...  ...               ...                    ...
# 641  2016  Summer  SWE            Silver                      3
# 642  2016  Summer  TUN            Bronze                      1
# 643  2016  Summer  TUR              Gold                      1
# 644  2016  Summer  USA              Gold                      7
# 645  2016  Summer  UZB            Bronze                      1
#
# [646 rows x 5 columns]

# %% [markdown]
# 16. En que deportes/eventos Mexico ha ganada la moyor cantidad de medallas?

# %%
q="""
SELECT
    Team,
    Sport,
    Event,
    Year,
    Count(*) as Total_medals
FROM
    f
WHERE
    Team= 'Mexico'
    and Sport = 'Football'
    
GROUP BY
    Year
ORDER BY
    Year DESC

"""
fut_mex_medals = sqldf(q)

fut_mex_medals
# Out:
#      Team     Sport                    Event  Year  Total_medals
# 0  Mexico  Football  Football Men's Football  2016             2
# 1  Mexico  Football  Football Men's Football  2012             1
# 2  Mexico  Football  Football Men's Football  1996             3
# 3  Mexico  Football  Football Men's Football  1992             2
# 4  Mexico  Football  Football Men's Football  1972             1
# 5  Mexico  Football  Football Men's Football  1968             2
# 6  Mexico  Football  Football Men's Football  1964             3

# %% [markdown]
# ## Desgloza todos los juegos Olimpicos en lo que gano mexico medallas en Footbally y cuantas medalles gano en cada uno de ellos.
